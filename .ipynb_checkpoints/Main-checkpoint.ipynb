# %% [markdown]
# #Linear regression  >> y = b + m*x
# b = intercept
# m = slope
# x = feature or an input
# y = label or an output
# FIND m & b

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np

# %%
x = np.arange(0, 3 *np.pi, 0.1 )
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave Form")
plt.show()

# %%
data = np.array([1, 2, 3, 4, 5])
a = pd.Series(data)
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
df = pd.DataFrame({'one':[10, 20, 30, 40, 50, 2000],
                  'two':[1000, 0, 30, 40, 50, 60]})
print(df.replace({1000:10, 2000:60}))
# Out:
#    one  two
# 0   10   10
# 1   20    0
# 2   30   30
# 3   40   40
# 4   50   50
# 5   60   60

# %%
data1 = pd.read_csv('ds_salaries.csv')
data1
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
print(data1.loc[2:6,['job_title','salary']])
# Out:
#                    job_title  salary
# 2          Big Data Engineer   85000
# 3       Product Data Analyst   20000
# 4  Machine Learning Engineer  150000
# 5               Data Analyst   72000
# 6        Lead Data Scientist  190000

# %%
from sqlalchemy import create_engine

# %%
data2 = pd.read_csv('ds_salaries.csv')

engine = create_engine('sqlite:///:memory:')

data2.to_sql('data_table', engine)

res1 = pd.read_sql_query('SELECT * FROM data_table', engine)

print('Result 1')
print(res1)
print('')

res2 = pd.read_sql_query('SELECT remote_ratio, sum(salary) FROM data_table group by remote_ratio', engine)
print('Result 2')
print(res2)
# Out:
# Result 1
#      index  Unnamed: 0  work_year experience_level employment_type  \
# 0        0           0       2020               MI              FT
# 1        1           1       2020               SE              FT
# 2        2           2       2020               SE              FT
# 3        3           3       2020               MI              FT
# 4        4           4       2020               SE              FT
# ..     ...         ...        ...              ...             ...
# 602    602         602       2022               SE              FT
# 603    603         603       2022               SE              FT
# 604    604         604       2022               SE              FT
# 605    605         605       2022               SE              FT
# 606    606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
from pandas.io import sql

# %%
#sql.execute('INSERT INTO data_table VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?)', engine, params=[('index',608,2023,'SE','FT','Data scientist',300000.,'KSH',3000,'KE',50,'KE','M')])

#res3 = pd.read_sql_query('SELECT Unnamed.0.work_year.experience_level.employment_type.job_title.salary.salary_currency.salary_in_usd.employee_residence.remote_ratio.company_location.company_size FROM data_table', engine)
#print(res3)

# %%
from sqlalchemy import create_engine
from pandas.io import sql

# %%
data3 = pd.read_csv('AYUSHHospitals.csv')
data3
# Out:
#                                          Srl no.                 State / UT  \
# 0                                            NaN                        NaN
# 1                                             -1                         -2
# 2                                              1             Andhra Pradesh
# 3                                              2          Arunachal Pradesh
# 4                                              3                      Assam
# 5                                              4                      Bihar
# 6                                              5               Chhattisgarh
# 7                                              6                      Delhi
# 8                                              7                        Goa
# 9                                              8                    Gujarat
# 10                                             9                    Haryana
# ...

# %%
data3 = pd.read_csv('AYUSHHospitals.csv')
engine = create_engine('sqlite:///:memory:')
data3.to_sql('data_table', engine)

sql.execute('Delete from data_table where Srl_no = (?)', engine, params=[25])

res3 = pd.read_sql_query('SELECT Srl_no.State/UT.Number_of_Hospitals.Unnamed.Unnamed.Unnamed.Number_of_Beds.Unnamed.Unnamed.Unnamed FROM data_table', engine)

print(res3)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\programs\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#
# File ~\programs\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: no such column: Srl_no
#
# The above exception was the direct cause of the following exception:
#
# ...
